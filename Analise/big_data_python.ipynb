# %%
# https://www.kaggle.com/datasets/ealtman2019/ibm-transactions-for-anti-money-laundering-aml
import pandas as pd

pd.options.display.float_format = "{:,.2f}".format


tabela = pd.read_csv("large.csv", nrows=10000)
display(tabela)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # https://www.kaggle.com/datasets/ealtman2019/ibm-transactions-for-anti-money-laundering-aml
# ----> 2 import pandas as pd
#       4 pd.options.display.float_format = "{:,.2f}".format
#       7 tabela = pd.read_csv("large.csv", nrows=10000)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pd.options.display.float_format = "{:,.2f}".format

tabela = pd.DataFrame()
for chunk in pd.read_csv("large.csv", chunksize=10000):
    colunas = ["Amount Received", "Receiving Currecy", "Amount Paid"]
    chunk_filtrado = chunk[colunas]
    resumo = chunk_filtrado.groupby("Receiving Currecy", as_index=False).sum()
    tabela = pd.concat([tabela,resumo])
