# %%
# Big Data
#   ↓
# Problemas do CSV
#  → Arquivos grandes
#  → Leitura lenta
# → Sem compressão
#  → Sem tipagem
#  ↓
# Necessidade de Computação Distribuída / Clusters
#  ↓
# Biblioteca Polars
#  → Carregar dados (read_csv)
#  → Visualizar (head)
#  → Selecionar (select)
#  → Filtrar (filter)
#  → Agrupar (group_by + agg)
#  → Criar colunas (with_columns)
#  ↓
# Formatos de Arquivos
# → CSV (simples, universal)
#  → JSON (estruturado)
#  → Parquet (Big Data)
#  → Avro (streaming)
#  → ORC (Hadoop)
#  ↓
# Parquet
# → Armazenamento colunar
# → Compressão eficiente
#  → Otimizado para análise
#  → Usado em Spark, Hadoop, Data Lakes
#  ↓
# Carregamento de Dados
# → Eager Execution
#      - Carrega tudo na memória
#      - Simples, mas pesado
#  → Lazy Execution
#      - Cria plano de execução
#      - Só processa com collect()
#      - Vantagens: menos memória, otimização, leitura seletiva
#  ↓
# Funções Polars
#  → read_csv() → eager
#  → scan_csv() → lazy
#  → read_parquet() → eager
#  → scan_parquet() → lazy
#  ↓
# Trabalhando com Parquet
#  → Salvar: write_parquet("dados.parquet")
#  → Ler: read_parquet("dados.parquet")
#  ↓
# Exercício Proposto
#  → Carregar dataset
#  → Calcular média de vendas
#  → Filtrar vendas acima de valor
#  → Agrupar por categoria
#  → Salvar resultado em Parquet -->
