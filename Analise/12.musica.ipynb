# %%
import polars as pl
import pandas as pd
import numpy as pd
import matplotlib as plt
import seaborn as sns
from IPython.display import display
from scipy import stats
from scipy.stats import pearsonr
import polars as pl

arquivo_info = 'Music Info.csv'
arquivo_user = 'User Listening History.csv'

# %%
# qual genero tem mais musicas não são tocadas?
nao_tocadas = df_merge.filter(pl.col("plays").is_null()).group_by("genre").agg(pl.len().alias("as_piores")).sort("as_piores", descending=True)
nao_tocadas
